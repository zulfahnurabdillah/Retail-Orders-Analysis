# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
from sqlalchemy import create_engine
import sqlalchemy as sal
# !pip install pyodbc
import pyodbc

# %%
df = pd.read_csv("orders.csv", na_values=['Not Available','unknown'])

# %%
df.head(20)
# Out:
#     order_id  order_date       ship_mode      segment        country  \
# 0          1  2023-03-01    Second Class     Consumer  United States
# 1          2  2023-08-15    Second Class     Consumer  United States
# 2          3  2023-01-10    Second Class    Corporate  United States
# 3          4  2022-06-18  Standard Class     Consumer  United States
# 4          5  2022-07-13  Standard Class     Consumer  United States
# 5          6  2022-03-13             NaN     Consumer  United States
# 6          7  2022-12-28  Standard Class     Consumer  United States
# 7          8  2022-01-25  Standard Class     Consumer  United States
# 8          9  2023-03-23             NaN     Consumer  United States
# 9         10  2023-05-16  Standard Class     Consumer  United States
# 10        11  2023-03-31             NaN     Consumer  United States
# 11        12  2023-12-25             NaN     Consumer  United States
# 12        13  2022-02-11  Standard Class     Consumer  United States
# ...

# %%
df.tail(20)
# Out:
#       order_id  order_date       ship_mode      segment        country  \
# 9974      9975  2022-11-17  Standard Class  Home Office  United States
# 9975      9976  2023-12-16  Standard Class  Home Office  United States
# 9976      9977  2022-09-11  Standard Class  Home Office  United States
# 9977      9978  2023-12-03  Standard Class  Home Office  United States
# 9978      9979  2023-06-05  Standard Class  Home Office  United States
# 9979      9980  2023-10-12  Standard Class  Home Office  United States
# 9980      9981  2023-06-26    Second Class     Consumer  United States
# 9981      9982  2022-11-14     First Class     Consumer  United States
# 9982      9983  2023-05-27  Standard Class     Consumer  United States
# 9983      9984  2022-09-14  Standard Class     Consumer  United States
# 9984      9985  2023-08-04  Standard Class     Consumer  United States
# 9985      9986  2023-09-30  Standard Class     Consumer  United States
# ...

# %%
df['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', nan, 'First Class', 'Same Day'],
#       dtype=object)

# %%
df['discount']=df['list_price']*df['discount_percent']*.01
df['sale_price']=df['list_price']-df['discount']
df['profit']=df['sale_price']-df['cost_price']

# %%
pd.to_datetime(df['Order Date'],format="%Y-%m-%d")
# Out:
# 0      2023-03-01
# 1      2023-08-15
# 2      2023-01-10
# 3      2022-06-18
# 4      2022-07-13
#           ...
# 9989   2023-02-18
# 9990   2023-03-17
# 9991   2022-08-07
# 9992   2022-11-19
# 9993   2022-07-17
# Name: Order Date, Length: 9994, dtype: datetime64[ns]

# %%
df.drop(columns=['list_price','cost_price','discount_percent'],inplace=True)

# %%
print("any missing values?",df.isnull () .values.any())
df.isnull() .sum()
# Out:
# any missing values? True
# order_id        0
# order_date      0
# ship_mode       6
# segment         0
# country         0
# city            0
# state           0
# postal_code     0
# region          0
# category        0
# sub_category    0
# product_id      0
# quantity        0
# discount        0
# sale_price      0
# profit          0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
dup_data=df.duplicated() .any()
print ("are there any duplicate value?",dup_data)
# Out:
# are there any duplicate value? False

# %%
df.rename(columns={'Order Id':'order_id','City':'city'})
df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(' ','_')
df.head()
# Out:
#    order_id  order_date       ship_mode    segment        country  \
# 0         1  2023-03-01    Second Class   Consumer  United States
# 1         2  2023-08-15    Second Class   Consumer  United States
# 2         3  2023-01-10    Second Class  Corporate  United States
# 3         4  2022-06-18  Standard Class   Consumer  United States
# 4         5  2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   sub_category       product_id  cost_price  list_price  quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# ...

# %%
pyodbc.drivers()
# Out:
# ['SQL Server',
#  'SQL Server Native Client RDA 11.0',
#  'ODBC Driver 17 for SQL Server']

# %%
engine = sal.create_engine('mssql://DESKTOP-JBIISF7/Retail_Orders?driver=ODBC+Driver+17+for+SQL+Server')
conn=engine.connect()

# %%
df.to_sql('df_retail',con=conn , index=False, if_exists= 'append')
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\engine\base.py:2116, in Connection._exec_insertmany_context(self, dialect, context)
#    2115     else:
# -> 2116         dialect.do_execute(
#    2117             cursor,
#    2118             sub_stmt,
#    2119             sub_params,
#    2120             context,
#    2121         )
#    2123 except BaseException as e:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\engine\default.py:924, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     923 def do_execute(self, cursor, statement, parameters, context=None):
# --> 924     cursor.execute(statement, parameters)
#
# ...

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_mode', 'segment', 'country', 'city',
#        'state', 'postal_code', 'region', 'category', 'sub_category',
#        'product_id', 'quantity', 'discount', 'sale_price', 'profit'],
#       dtype='object')
